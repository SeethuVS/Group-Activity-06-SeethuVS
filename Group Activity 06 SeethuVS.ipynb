# %%
import pandas as pd
data=pd.read_csv("Dataset_w6.csv")
data.head(10)
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia            652864.0
# 1              Albania  SouthernEurope             28748.0
# 2              Algeria  NorthernAfrica           2381741.0
# 3               Angola    MiddleAfrica           1246700.0
# 4  Antigua and Barbuda       Caribbean               442.0
# 5            Argentina    SouthAmerica           2780400.0
# 6              Armenia     WesternAsia             29743.0
# 7            Australia         Oceania           7692060.0
# 8              Austria   WesternEurope             83871.0
# 9           Azerbaijan     WesternAsia             86600.0
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                         35530.0                         623.2
# 1                          2930.0                        3984.2
# 2                         41318.0                        4154.1
# ...

# %% [markdown]
# # . Find out how many countries are there in the dataset

# %%
data['country'].count()
# Out:
# 196

# %% [markdown]
# # # Find out how many countries with respect to the region are available in the
# dataset

# %%
df=data.groupby(['Region'])['country'].count()
df
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %% [markdown]
# # On average which region has the highest
# a. GDP per capita (current US$)
# b. International trade: Imports (million US$)

# %%
import pandas as pd
data=pd.read_csv("Dataset_w6.csv")
data1=data[['Region','GDP per capita (current US$)']].groupby('Region').mean().sort_values(['GDP per capita (current US$)'],ascending=False)
data1
# Out:
#                    GDP per capita (current US$)
# Region
# NorthernAmerica                    57659.000000
# WesternEurope                      55387.128571
# Oceania                            44823.250000
# NorthernEurope                     42098.220000
# EasternAsia                        27967.614286
# WesternAsia                        17013.938889
# Caribbean                          15135.562500
# SouthernEurope                     14462.741667
# South-easternAsia                  10299.027273
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Polynesia                           8686.520000
# SouthAmerica                        8499.775000
# CentralAmerica                      6348.137500
# Micronesia                          5008.300000
# CentralAsia                         4329.880000
# SouthernAfrica                      4191.900000
# NorthernAfrica                      3934.960000
# ...

# %%
import pandas as pd
data=pd.read_csv("Dataset_w6.csv")
data2=data[['Region','International trade: Imports (million US$)']].groupby('Region').mean().sort_values(['International trade: Imports (million US$)'],ascending=False)
data2
# Out:
#                    International trade: Imports (million US$)
# Region
# NorthernAmerica                                 663552.250000
# EasternAsia                                     451995.000000
# WesternEurope                                   407498.428571
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# South-easternAsia                                98324.636364
# EasternEurope                                    85243.900000
# SouthernEurope                                   76666.666667
# SouthernAsia                                     58199.333333
# CentralAmerica                                   57031.500000
# WesternAsia                                      46025.555556
# NorthernAfrica                                   35034.400000
# SouthAmerica                                     32885.666667
# SouthernAfrica                                   18005.600000
# ...

# %% [markdown]
# # . Find out which region has more consistent with respect to GDP per capita
# (current US$)

# %%
data1=data[['Region','GDP per capita (current US$)']].groupby('Region').var().sort_values(['GDP per capita (current US$)'],ascending=True)
data1
# Out:
#                    GDP per capita (current US$)
# Region
# WesternAfrica                      6.643805e+05
# NorthernAfrica                     9.500529e+05
# SouthernAfrica                     4.741729e+06
# SouthernAsia                       8.155069e+06
# EasternAfrica                      1.380964e+07
# CentralAsia                        1.724089e+07
# CentralAmerica                     1.747609e+07
# SouthAmerica                       1.826457e+07
# Micronesia                         2.323886e+07
# MiddleAfrica                       2.782400e+07
# EasternEurope                      2.932752e+07
# Polynesia                          4.838942e+07
# Oceania                            8.525438e+07
# SouthernEurope                     9.104410e+07
# Melanesia                          1.919844e+08
# Caribbean                          2.125581e+08
# South-easternAsia                  2.660752e+08
# WesternAsia                        3.538970e+08
# ...

# %%
import matplotlib.pyplot as plt
data1=data[['Region','GDP per capita (current US$)']].groupby('Region').var().sort_values(['GDP per capita (current US$)'],ascending=True).plot(kind='bar')
plt.show()
